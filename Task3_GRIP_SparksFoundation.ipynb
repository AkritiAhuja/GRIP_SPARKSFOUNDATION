# %% [markdown]
# **Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
from sklearn.tree import export_graphviz
import pydotplus 
from sklearn.externals.six import StringIO 
from IPython.display import Image

# %% [markdown]
# **Importing File**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-45bdc8af-0f26-432f-9c1d-00ef403e32c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45bdc8af-0f26-432f-9c1d-00ef403e32c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv
# ...

# %%
import pandas as pd
data= pd.read_csv("Iris.csv",header=0)
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Splitting of Data**

# %%
feature_colums=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
X=data[feature_colums]
Y=data.Species

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
dtc=DecisionTreeClassifier()
dtc=dtc.fit(X_train,Y_train)
Y_pred=dtc.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# **Plotting Graph**

# %%
dot_data = StringIO()
export_graphviz(dtc, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_colums,class_names=['0','1','2','3'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 
graph.write_png('Spicies.png')
Image(graph.create_png())

# %% [markdown]
# **Predicting for any value**

# %%
Yval=dtc.predict(np.array([5.0,3.6,1.4,0.2]).reshape(1,-1))
Yval
# Out:
# array(['Iris-setosa'], dtype=object)
